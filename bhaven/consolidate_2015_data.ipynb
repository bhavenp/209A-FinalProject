# %%
import warnings
#warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import os
import create_aggregate_df as agg_df

# %matplotlib inline
pd.set_option('display.max_columns', None);

# %%
path = "../data/2015_loan_data/";
loans_2015_all = agg_df.create_aggregate_df(path);
loans_2015_all.head()
# Out:
# LoanStats_2015_B.csv
# /Users/bhavenpatel/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# LoanStats_2015_C.csv
# /Users/bhavenpatel/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2903: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   if self.run_code(code, result):
# LoanStats_2015_D.csv
# LoanStats_2015_E.csv
# LoanStats_2015_F.csv
# LoanStats_2015_G.csv
# LoanStats_2015_H.csv
#    id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0 NaN        NaN      20000        20000          20000.0   36 months
# 1 NaN        NaN      10000        10000          10000.0   36 months
# 2 NaN        NaN      18000        18000          18000.0   36 months
# 3 NaN        NaN      20000        20000          20000.0   36 months
# ...

# %%
loans_2015_all.shape
# Out:
# (421095, 145)

# %%
loans_2015_all = loans_2015_all.loc[loans_2015_all.loan_status != 'Current', :];
loans_2015_all.shape
# Out:
# (346828, 145)

# %%
print(loans_2015_all.policy_code.unique())
# Out:
# [1]

# %%
#make category for whether the loan defaulted
loans_2015_all['default'] = 1;
loans_2015_all.loc[loans_2015_all.loan_status == 'Fully Paid', 'default'] = 0;

# %%
#calculate the def
ratio = loans_2015_all.default.sum() / loans_2015_all.default.count()
print('Default Percentage = {0}'.format(ratio))
# Out:
# Default Percentage = 0.22238400590494423
